# %% [markdown]
# ## gensim으로 네이버 기사 토픽 모델링 해보기

# %% [markdown]
# > 토픽 모델링을 적용하기 위해 텍스트를 처리합니다.
#
# > 토픽 모델링 라이브러리인 gensim을 사용해봅니다.

# %% [markdown]
# ### 1. 토픽 모델링을 위한 라이브러리 불러오기

# %%
from tqdm import tqdm_notebook # progress bar
from konlpy.tag import Mecab #Mecab, Okt 등 형태소 분석기 불러오기
import numpy as np
import string # 특수문자
import re
import warnings # 경고 알림 제거
import pickle
from gensim import corpora # corpus LDA로 돌릴 수 있는 형태로 변환해주는 기능 
from gensim import models
import matplotlib.pyplot as plt
# %matplotlib inline

warnings.filterwarnings("ignore", category=DeprecationWarning) # 경고 알림이 뜨면 모두 무시합니다.

# %% [markdown]
# ### 2. 텍스트 전처리 함수 만들기

# %%
def read_documents(input_file_name):
    """문서들을 주어진 이름의 파일로부터 읽어들여 돌려준다."""
    
    corpus = []
    
    with open(input_file_name, 'rb') as f:
        temp_corpus = pickle.load(f)
        
    for page in temp_corpus:
        corpus += page
    
    return corpus

def text_cleaning(docs):
    # 한국어를 제외한 글자를 제거하는 함수.
    for doc in docs:
        doc = re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", doc)

    return docs

def define_stopwords(path):
    
    SW = set()
    # 불용어를 추가하는 방법 1.
    for i in string.punctuation:
        SW.add(i)

    # 불용어를 추가하는 방법 2.
    # stopwords-ko.txt에 직접 추가
    
    with open(path) as f:
        for word in f:
            SW.add(word)

    return SW


def text_tokenizing(corpus, tokenizer):
    
    mecab = Mecab()
    token_corpus = []
    

    if tokenizer == "noun":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            token_text = mecab.nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
                
            token_corpus.append(token_text)
            
    elif tokenized == "morph":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            token_text = mecab.morphs(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)

    elif tokenizer == "word":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            token_text = corpus[n].split()
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
        

    return token_corpus

# %% [markdown]
# 문서 읽기의 과정은 앞서 단어 임베딩의 경우와 다르지 않다. 다음 과정은 문서-단어 행렬을 만드는 과정이다.

# %%
input_file_name = "test_content.pk"
documents = read_documents(input_file_name)
SW = define_stopwords("stopwords-ko.txt")
cleaned_text = text_cleaning(documents)
tokenized_text = text_tokenizing(cleaned_text, tokenizer="noun") #tokenizer= "noun" or "word"
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Preprocessing', max=1.0, style=ProgressStyle(description_…

# %%
tokenized_text
# Out:
# [['최근',
#   '인터넷',
#   '개인',
#   '방송',
#   '매개',
#   '선정',
#   '폭력',
#   '영상',
#   '불법',
#   '정보',
#   '유통',
#   '인터넷',
#   '개인',
#   '방송',
#   '규제',
#   '강화',
#   '지적',
#   '제기',
#   '인터넷',
#   '개인',
#   '방송',
#   '특성',
#   '불법',
#   '정보',
#   '유통',
#   '여부',
#   '방송',
#   '송신',
#   '이후',
#   '판단',
#   '현행법',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '송신',
#   '영상',
#   '콘텐츠',
#   '저장',
#   '의무',
#   '규정',
#   '규제',
#   '실정',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '운영',
#   '관리',
#   '정보',
#   '통신망',
#   '유통',
#   '정보',
#   '일정',
#   '기간',
#   '동안',
#   '보관',
#   '의무',
#   '위반',
#   '경우',
#   '과태료',
#   '부과',
#   '인터넷',
#   '개인',
#   '방송',
#   '매개',
#   '불법',
#   '정보',
#   '유통',
#   '신설',
#   '현행법',
#   '복수',
#   '진행자',
#   '콘텐츠',
#   '실시간',
#   '정보',
#   '통신망',
#   '이용자',
#   '제공',
#   '인터넷',
#   '개인',
#   '방송',
#   '정의',
#   '규제',
#   '마련',
#   '인터넷',
#   '개인',
#   '방송',
#   '도박',
#   '성매매',
#   '음란',
#   '명예훼손',
#   '욕설',
#   '차별',
#   '비하',
#   '발언',
#   '선정',
#   '폭력',
#   '방송',
#   '발생',
#   '불법',
#   '정보',
#   '청소년',
#   '유해',
#   '정보',
#   '정보',
#   '통신망',
#   '유통',
#   '규제',
#   '규제',
#   '필요',
#   '지속',
#   '지적',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '청소년',
#   '보호',
#   '책임자',
#   '지정',
#   '불법',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '위반',
#   '경우',
#   '과태료',
#   '부과',
#   '정보',
#   '통신망',
#   '불법',
#   '정보',
#   '청소년',
#   '유해',
#   '정보',
#   '유통',
#   '정보',
#   '통신망',
#   '청소년',
#   '유해',
#   '정보',
#   '청소년',
#   '보호',
#   '청소년',
#   '보호',
#   '책임자',
#   '지정',
#   '대상자',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '추가',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '운영',
#   '관리',
#   '정보',
#   '통신망',
#   '불법',
#   '정보',
#   '유통',
#   '사정',
#   '인식',
#   '경우',
#   '지체',
#   '해당',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '신설',
#   '위반',
#   '불법',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '천만',
#   '이하',
#   '과태료',
#   '부과',
#   '조제',
#   '신설',
#   '인터넷',
#   '이용',
#   '대중',
#   '미디어',
#   '콘텐츠',
#   '생산',
#   '다양',
#   '방송',
#   '창작자',
#   '인터넷',
#   '개인',
#   '방송',
#   '제공',
#   '플랫',
#   '급증',
#   '청소년',
#   '유해',
#   '정보',
#   '불법',
#   '정보',
#   '추세',
#   '청소년',
#   '유해',
#   '정보',
#   '불법',
#   '정보',
#   '관련',
#   '정부',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '자율',
#   '규제',
#   '강화',
#   '시도',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '청소년',
#   '유해',
#   '정보',
#   '불법',
#   '정보',
#   '유통',
#   '모니터링',
#   '자율',
#   '규제',
#   '가이드라인',
#   '시행',
#   '명시',
#   '근거',
#   '마련',
#   '자율',
#   '규제',
#   '한계',
#   '지적',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '청소년',
#   '유해',
#   '정보',
#   '불법',
#   '정보',
#   '유통',
#   '모니터링',
#   '자율',
#   '규제',
#   '가이드라인',
#   '시행',
#   '청소년',
#   '유해',
#   '정보',
#   '불법',
#   '정보',
#   '규제',
#   '관련',
#   '자율',
#   '규제',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '책임',
#   '정부',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '이용자',
#   '단체',
#   '자율',
#   '규제',
#   '활동',
#   '지원',
#   '조제',
#   '정보',
#   '통신망',
#   '용촉',
#   '정보',
#   '보호',
#   '시책',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '이용자',
#   '단체',
#   '자율',
#   '규제',
#   '활성',
#   '추가',
#   '조제',
#   '신설',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '단체',
#   '청소년',
#   '유해',
#   '정보',
#   '불법',
#   '정보',
#   '유통',
#   '모니터링',
#   '자율',
#   '규제',
#   '가이드라인',
#   '시행',
#   '신설',
#   '현행법',
#   '신문',
#   '발행',
#   '자유',
#   '독립',
#   '기능',
#   '보장',
#   '사회',
#   '책임',
#   '신문',
#   '산업',
#   '지원',
#   '육성',
#   '언론',
#   '자유',
#   '신장',
#   '민주',
#   '여론',
#   '형성',
#   '기여',
#   '제정',
#   '최근',
#   '블로그',
#   '개인',
#   '방송',
#   '다양',
#   '매체',
#   '등장',
#   '언론',
#   '환경',
#   '변화',
#   '정보',
#   '홍수',
#   '허위',
#   '정보',
#   '대중',
#   '피로도',
#   '증가',
#   '신문',
#   '인터넷',
#   '신문',
#   '기능',
#   '강화',
#   '지적',
#   '지속',
#   '제기',
#   '여론',
#   '형성',
#   '신문',
#   '산업',
#   '지원',
#   '강화',
#   '필요',
#   '목적',
#   '국민',
#   '복리',
#   '증진',
#   '독자',
#   '권익',
#   '보호',
#   '추가',
#   '신문',
#   '인터넷',
#   '신문',
#   '공정',
#   '공익',
#   '강화',
#   '원칙',
#   '규정',
#   '신설',
#   '신문',
#   '산업',
#   '진흥',
#   '문화',
#   '체육관',
#   '광부',
#   '장관',
#   '신문',
#   '산업',
#   '진흥',
#   '기본',
#   '계획',
#   '수립',
#   '신설',
#   '일반',
#   '일간',
#   '신문',
#   '사업자',
#   '편집',
#   '위원회',
#   '의무',
#   '독자',
#   '권리',
#   '보호',
#   '독자',
#   '권익',
#   '위원회',
#   '회의',
#   '결과',
#   '신문',
#   '인터넷',
#   '신문',
#   '공개',
#   '신문',
#   '산업',
#   '지원',
#   '세제',
#   '금융',
#   '지원',
#   '근거',
#   '마련',
#   '신설',
#   '지역',
#   '언론',
#   '발전',
#   '일부',
#   '규모',
#   '인터넷',
#   '뉴스',
#   '서비스',
#   '사업자',
#   '지역',
#   '신문',
#   '지역',
#   '방송',
#   '기사',
#   '일정',
#   '비율',
#   '이상',
#   '제공',
#   '언론',
#   '진흥',
#   '기금',
#   '공정',
#   '투명',
#   '강화',
#   '언론',
#   '진흥',
#   '기금',
#   '관리',
#   '운용',
#   '주체',
#   '문화',
#   '체육관',
#   '광부',
#   '장관',
#   '변경',
#   '최근',
#   '정보',
#   '통신망',
#   '유통',
#   '인터넷',
#   '방송',
#   '선정',
#   '폭력성',
#   '문제',
#   '발생',
#   '무분별',
#   '음란',
#   '콘텐츠',
#   '유통',
#   '실태',
#   '개선',
#   '방송',
#   '통신',
#   '위원회',
#   '반복',
#   '음란',
#   '방송',
#   '인터넷',
#   '방송',
#   '진행자',
#   '이용',
#   '해지',
#   '실시간',
#   '인터넷',
#   '방송',
#   '제공',
#   '사이트',
#   '폐쇄',
#   '시정',
#   '요구',
#   '결정',
#   '방송',
#   '통신',
#   '위원회',
#   '인터넷',
#   '방송',
#   '모니터링',
#   '현실',
#   '실제',
#   '인터넷',
#   '방송',
#   '사업자',
#   '인터넷',
#   '방송',
#   '음란',
#   '불법',
#   '정보',
#   '모니터링',
#   '불법',
#   '정보',
#   '유통',
#   '필요',
#   '조치',
#   '음란',
#   '인터넷',
#   '방송',
#   '성행',
#   '현실',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '음란',
#   '불법',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '인터넷',
#   '개인',
#   '방송',
#   '가이드라인',
#   '시행',
#   '정보',
#   '통신망',
#   '음란',
#   '방송',
#   '유통',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '운영',
#   '관리',
#   '정보',
#   '통신망',
#   '불법',
#   '정보',
#   '유통',
#   '사정',
#   '인식',
#   '경우',
#   '지체',
#   '해당',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '신설',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '인터넷',
#   '개인',
#   '방송',
#   '불법',
#   '정보',
#   '유통',
#   '실시간',
#   '인터넷',
#   '개인',
#   '방송',
#   '모니터링',
#   '인터넷',
#   '개인',
#   '방송',
#   '가이드라인',
#   '시행',
#   '신설',
#   '삭제',
#   '유통',
#   '차단',
#   '대상',
#   '불법',
#   '정보',
#   '구체',
#   '내용',
#   '인터넷',
#   '개인',
#   '방송',
#   '가이드라인',
#   '포함',
#   '내용',
#   '필요',
#   '사항',
#   '대통령령',
#   '신설',
#   '위반',
#   '불법',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '위반',
#   '인터넷',
#   '개인',
#   '방송',
#   '가이드라인',
#   '시행',
#   '천만',
#   '이하',
#   '과태료',
#   '부과',
#   '조제',
#   '신설',
#   '최근',
#   '인터넷',
#   '이용',
#   '대중',
#   '미디어',
#   '콘텐츠',
#   '생산',
#   '다양',
#   '일환',
#   '복수',
#   '진행자',
#   '게임',
#   '토크',
#   '음악',
#   '교육',
#   '다양',
#   '종류',
#   '프로그램',
#   '정보',
#   '통신망',
#   '이용자',
#   '제공',
#   '인터넷',
#   '개인',
#   '방송',
#   '급증',
#   '인터넷',
#   '개인',
#   '방송',
#   '정의',
#   '규제',
#   '제도',
#   '상태',
#   '인터넷',
#   '개인',
#   '방송',
#   '선정',
#   '폭력',
#   '내용',
#   '발생',
#   '사회',
#   '문제',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '현행법',
#   '특수',
#   '유형',
#   '통신',
#   '사업자',
#   '규정',
#   '현행',
#   '신고',
#   '등록제',
#   '변경',
#   '사업자',
#   '음란',
#   '불법',
#   '정보',
#   '삭제',
#   '유통',
#   '차단',
#   '의무',
#   '부과',
#   '인터넷',
#   '개인',
#   '방송',
#   '폐해',
#   '방지',
#   '조제',
#   '다목',
#   '신설',
#   '인터넷',
#   '이용',
#   '대중',
#   '미디어',
#   '콘텐츠',
#   '생산',
#   '다양',
#   '인터넷',
#   '개인',
#   '방송',
#   '매개',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '급증',
#   '최근',
#   '인터넷',
#   '개인',
#   '방송',
#   '매개',
#   '선정',
#   '폭력',
#   '영상',
#   '불법',
#   '정보',
#   '유통',
#   '사회',
#   '문제',
#   '현행',
#   '법률',
#   '불법',
#   '정보',
#   '유통',
#   '이용자',
#   '정보',
#   '통신망',
#   '이용',
#   '제한',
#   '근거',
#   '규정',
#   '인터넷',
#   '개인',
#   '방송',
#   '유통',
#   '불법',
#   '정보',
#   '근절',
#   '지적',
#   '제기',
#   '인터넷',
#   '개인',
#   '방송',
#   '불법',
#   '정보',
#   '유통',
#   '경우',
#   '해당',
#   '인터넷',
#   '개인',
#   '방송',
#   '매개',
#   '정보',
#   '통신',
#   '서비스',
#   '제공',
#   '운영',
#   '관리',
#   '정보',
#   '통신망',
#   '불법',
#   '정보',
#   '유통',
#   '이용',
#   '제한',
#   '인터넷',
#   '개인',
#   '방송',
#   '불법',
#   '정보',
#   '유통',
#   '방지',
#   '신설',
#   '최근',
#   '스마트폰',
#   '태블릿',
#   '스마트',
#   '기기',
#   '대중',
#   '기기',
#   '이용',
#   '인터넷',
#   '개인',
#   '방송',
#   '사용',
#   '증가',
#   '개인',
#   '어디',
#   '영상',
#   '송신',
#   '시청자',
#   '양방향',
#   '소통',
#   '인터넷',
#   '개인',
#   '방송',
#   '운전자',
#   '운전',
#   '동시',
#   '진행',
#   '전방',
#   '주시',
#   '의무',
#   '사례',
#   '발생',
#   '운전자',
#   '운전',
#   '영상',
#   '표시',
#   '장치',
#   '사용',
#   '특정',
#   '다수',
#   '사람',
#   '실시간',
#   '영상',
#   '송신',
#   '행위',
#   '금지',
#   '교통안전',
#   '강화',
#   '조제',
#   '신설',
#   '최근',
#   '인터넷',
#   '개인',
#   '방송',
#   '불법',
#   '유해',
#   '내용',
#   '사회',
#   '문제',
#   '제재',
#   '방안',
#   '방송',
#   '통신',
#   '위원회',
#   '이용',
#   '정지',
#   '자율',
#   '규제',
#   '권고',
#   '제재',
#   '실효',
#   '실정',
#   '한편',
#   '인터넷',
#   '개인',
#   '방송',
#   '진행자',
#   '선정',
#   '자극',
#   '방송',
#   '목적',
#   '사이버',
#   '머니',
#   '취득',
#   '규제',
#   '의견',
#   '제시',
#   '현행',
#   '부가',
#   '통신',
#   '사업자',
#   '신고',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '특수',
#   '유형',
#   '통신',
#   '사업자',
#   '지정',
#   '과학',
#   '기술',
#   '정보',
#   '통신부',
#   '장관',
#   '등록',
#   '사업자',
#   '책임',
#   '강화',
#   '인터넷',
#   '개인',
#   '방송',
#   '사업자',
#   '사이버',
#   '머니',
#   '한도',
#   '설정',
#   '건전',
#   '인터넷',
#   '개인',
#   '방송',
#   '이용',
#   '환경',
#   '기여',
#   '조제',
#   '다목',
#   '신설',
#   '세기',
#   '정보',
#   '시대',
#   '우리',
#   '사회',
#   '통신',
#   '매체',
#   '확산',
#   '블로그',
#   '트위터',
#   '페이스북',
#   '유튜브',
#   '개인',
#   '방송',
#   '개인',
#   '주도',
#   '매체',
#   '비중',
#   '최근',
#   '국민',
#   '소통',
#   '채널',
#   '증대',
#   '정치인',
#   '유튜브',
#   '참여',
#   '급증',
#   '일부',
#   '정치인',
#   '경우',
#   '유튜브',
#   '광고',
#   '수익',
#   '발생',
#   '정도',
#   '채널',
#   '성장',
#   '광고',
#   '수익',
#   '정치',
#   '자금',
#   '사용',
#   '여부',
#   '현행법',
#   '정치',
#   '활동',
#   '사람',
#   '정치',
#   '활동',
#   '관련',
#   '활동',
#   '발생',
#   '수입',
#   '위반',
#   '자유',
#   '정치',
#   '자금',
#   '사용',
#   '해석',
#   '명문',
#   '규정',
#   '혼란',
#   '자유',
#   '정치',
#   '활동',
#   '제약',
#   '실정',
#   '누구',
#   '정치',
#   '활동',
#   '관련',
#   '강연료',
#   '방송',
#   '출연료',
#   '출판',
#   '수입',
#   ...]]

# %%
print(tokenized_text[0])
# Out:
# ['최근', '인터넷', '개인', '방송', '매개', '선정', '폭력', '영상', '불법', '정보', '유통', '인터넷', '개인', '방송', '규제', '강화', '지적', '제기', '인터넷', '개인', '방송', '특성', '불법', '정보', '유통', '여부', '방송', '송신', '이후', '판단', '현행법', '인터넷', '개인', '방송', '사업자', '송신', '영상', '콘텐츠', '저장', '의무', '규정', '규제', '실정', '인터넷', '개인', '방송', '사업자', '운영', '관리', '정보', '통신망', '유통', '정보', '일정', '기간', '동안', '보관', '의무', '위반', '경우', '과태료', '부과', '인터넷', '개인', '방송', '매개', '불법', '정보', '유통', '신설', '현행법', '복수', '진행자', '콘텐츠', '실시간', '정보', '통신망', '이용자', '제공', '인터넷', '개인', '방송', '정의', '규제', '마련', '인터넷', '개인', '방송', '도박', '성매매', '음란', '명예훼손', '욕설', '차별', '비하', '발언', '선정', '폭력', '방송', '발생', '불법', '정보', '청소년', '유해', '정보', '정보', '통신망', '유통', '규제', '규제', '필요', '지속', '지적', '인터넷', '개인', '방송', '사업자', '청소년', '보호', '책임자', '지정', '불법', '정보', '삭제', '유통', '차단', '위반', '경우', '과태료', '부과', '정보', '통신망', '불법', '정보', '청소년', '유해', '정보', '유통', '정보', '통신망', '청소년', '유해', '정보', '청소년', '보호', '청소년', '보호', '책임자', '지정', '대상자', '인터넷', '개인', '방송', '사업자', '추가', '인터넷', '개인', '방송', '사업자', '운영', '관리', '정보', '통신망', '불법', '정보', '유통', '사정', '인식', '경우', '지체', '해당', '정보', '삭제', '유통', '차단', '신설', '위반', '불법', '정보', '삭제', '유통', '차단', '천만', '이하', '과태료', '부과', '조제', '신설', '인터넷', '이용', '대중', '미디어', '콘텐츠', '생산', '다양', '방송', '창작자', '인터넷', '개인', '방송', '제공', '플랫', '급증', '청소년', '유해', '정보', '불법', '정보', '추세', '청소년', '유해', '정보', '불법', '정보', '관련', '정부', '정보', '통신', '서비스', '제공', '단체', '자율', '규제', '강화', '시도', '정보', '통신', '서비스', '제공', '단체', '정보', '통신', '서비스', '제공', '청소년', '유해', '정보', '불법', '정보', '유통', '모니터링', '자율', '규제', '가이드라인', '시행', '명시', '근거', '마련', '자율', '규제', '한계', '지적', '정보', '통신', '서비스', '제공', '단체', '청소년', '유해', '정보', '불법', '정보', '유통', '모니터링', '자율', '규제', '가이드라인', '시행', '청소년', '유해', '정보', '불법', '정보', '규제', '관련', '자율', '규제', '정보', '통신', '서비스', '제공', '단체', '책임', '정부', '정보', '통신', '서비스', '제공', '단체', '이용자', '단체', '자율', '규제', '활동', '지원', '조제', '정보', '통신망', '용촉', '정보', '보호', '시책', '정보', '통신', '서비스', '제공', '단체', '이용자', '단체', '자율', '규제', '활성', '추가', '조제', '신설', '정보', '통신', '서비스', '제공', '단체', '청소년', '유해', '정보', '불법', '정보', '유통', '모니터링', '자율', '규제', '가이드라인', '시행', '신설', '현행법', '신문', '발행', '자유', '독립', '기능', '보장', '사회', '책임', '신문', '산업', '지원', '육성', '언론', '자유', '신장', '민주', '여론', '형성', '기여', '제정', '최근', '블로그', '개인', '방송', '다양', '매체', '등장', '언론', '환경', '변화', '정보', '홍수', '허위', '정보', '대중', '피로도', '증가', '신문', '인터넷', '신문', '기능', '강화', '지적', '지속', '제기', '여론', '형성', '신문', '산업', '지원', '강화', '필요', '목적', '국민', '복리', '증진', '독자', '권익', '보호', '추가', '신문', '인터넷', '신문', '공정', '공익', '강화', '원칙', '규정', '신설', '신문', '산업', '진흥', '문화', '체육관', '광부', '장관', '신문', '산업', '진흥', '기본', '계획', '수립', '신설', '일반', '일간', '신문', '사업자', '편집', '위원회', '의무', '독자', '권리', '보호', '독자', '권익', '위원회', '회의', '결과', '신문', '인터넷', '신문', '공개', '신문', '산업', '지원', '세제', '금융', '지원', '근거', '마련', '신설', '지역', '언론', '발전', '일부', '규모', '인터넷', '뉴스', '서비스', '사업자', '지역', '신문', '지역', '방송', '기사', '일정', '비율', '이상', '제공', '언론', '진흥', '기금', '공정', '투명', '강화', '언론', '진흥', '기금', '관리', '운용', '주체', '문화', '체육관', '광부', '장관', '변경', '최근', '정보', '통신망', '유통', '인터넷', '방송', '선정', '폭력성', '문제', '발생', '무분별', '음란', '콘텐츠', '유통', '실태', '개선', '방송', '통신', '위원회', '반복', '음란', '방송', '인터넷', '방송', '진행자', '이용', '해지', '실시간', '인터넷', '방송', '제공', '사이트', '폐쇄', '시정', '요구', '결정', '방송', '통신', '위원회', '인터넷', '방송', '모니터링', '현실', '실제', '인터넷', '방송', '사업자', '인터넷', '방송', '음란', '불법', '정보', '모니터링', '불법', '정보', '유통', '필요', '조치', '음란', '인터넷', '방송', '성행', '현실', '인터넷', '개인', '방송', '사업자', '음란', '불법', '정보', '삭제', '유통', '차단', '인터넷', '개인', '방송', '가이드라인', '시행', '정보', '통신망', '음란', '방송', '유통', '인터넷', '개인', '방송', '사업자', '운영', '관리', '정보', '통신망', '불법', '정보', '유통', '사정', '인식', '경우', '지체', '해당', '정보', '삭제', '유통', '차단', '신설', '인터넷', '개인', '방송', '사업자', '인터넷', '개인', '방송', '불법', '정보', '유통', '실시간', '인터넷', '개인', '방송', '모니터링', '인터넷', '개인', '방송', '가이드라인', '시행', '신설', '삭제', '유통', '차단', '대상', '불법', '정보', '구체', '내용', '인터넷', '개인', '방송', '가이드라인', '포함', '내용', '필요', '사항', '대통령령', '신설', '위반', '불법', '정보', '삭제', '유통', '차단', '위반', '인터넷', '개인', '방송', '가이드라인', '시행', '천만', '이하', '과태료', '부과', '조제', '신설', '최근', '인터넷' ...

# %% [markdown]
# ### 3. 토픽 모델링에 사용할 함수들 확인하기

# %%
# 문서-단어 행렬 만들기
# 어휘(vocabulary) 학습
dictionary = corpora.Dictionary(tokenized_text)
# 문서-단어 행렬(document-term matrix) 생성
corpus = [dictionary.doc2bow(text) for text in tokenized_text]

# %%
print(dictionary)
# Out:
# Dictionary(282 unique tokens: ['가이드라인', '강연료', '강화', '개선', '개인']...)

# %%
corpus[0][:5]
# Out:
# [(0, 7), (1, 1), (2, 8), (3, 1), (4, 44)]

# %%
# TFIDF 문서-단어 행렬 생성
tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
corpus_tfidf[0][:5]
# Out:
# []

# %%
model = models.ldamodel.LdaModel(corpus_tfidf, num_topics=4, id2word=dictionary)
# Out:
# /Users/yongha/opt/anaconda3/envs/yh/lib/python3.8/site-packages/gensim/models/ldamodel.py:821: RuntimeWarning: divide by zero encountered in double_scalars
#   perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)

# %%
model.show_topic(3, 10)
# Out:
# [('장관', 0.0035460987),
#  ('자유', 0.0035460987),
#  ('정보', 0.0035460987),
#  ('정도', 0.0035460987),
#  ('전방', 0.0035460987),
#  ('저장', 0.0035460987),
#  ('장치', 0.0035460987),
#  ('정의', 0.0035460987),
#  ('자율', 0.0035460987),
#  ('일환', 0.0035460987)]

# %% [markdown]
# ### 4. 토픽 모델링을 추가하여 코드 완성하기

# %%
# 토픽 개수, 키워드 개수를 정해주는 변수를 추가.
NUM_TOPICS = 2

NUM_TOPIC_WORDS = 50


def build_doc_term_mat(documents):
    # 문서-단어 행렬 만들어주는 함수.
    print("Building document-term matrix.")
    dictionary = corpora.Dictionary(documents)
    corpus = [dictionary.doc2bow(document) for document in documents]
        
    return corpus, dictionary


def print_topic_words(model):

    # 토픽 모델링 결과를 출력해 주는 함수.
    print("\nPrinting topic words.\n")
    
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

# document-term matrix를 만들고,
corpus, dictionary = build_doc_term_mat(tokenized_text)
# LDA를 실행.
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary, alpha="auto", eta="auto")
# 결과를 출력.
print_topic_words(model)
# Out:
# Building document-term matrix.
#
# Printing topic words.
#
# Topic ID: 0
# 	방송	0.04607158154249191
# 	정보	0.04459259659051895
# 	인터넷	0.043995097279548645
# 	개인	0.03461017832159996
# 	불법	0.026547877117991447
# 	유통	0.02382894791662693
# 	신설	0.016786225140094757
# 	사업자	0.014886061660945415
# 	통신	0.013442779891192913
# 	규제	0.013441822491586208
# 	통신망	0.01168040931224823
# 	제공	0.011544237844645977
# 	청소년	0.009813825599849224
# 	유해	0.009460910223424435
# 	신문	0.009273738600313663
# 	자율	0.009064081124961376
# 	단체	0.009052373468875885
# 	최근	0.0082304198294878
# 	삭제	0.007929583080112934
# 	이용	0.007591800298541784
# 	강화	0.0073242271319031715
# 	정치	0.007004073821008205
# 	서비스	0.006964326836168766
# 	활동	0.0069276499561965466
# 	차단	0.006750568747520447
# 	조제	0.006699450314044952
# 	음란	0.006417847704142332
# 	영상	0.006283437833189964
# 	시행	0.00606463011354208
# 	위원회	0.005852587521076202
# 	가이드라인	0.0058350227773189545
# 	콘텐츠	0.005802431143820286
# 	경우	0.00572545500472188
# 	보호	0.005567374173551798
# 	발생	0.005553102120757103
# 	산업	0.0053800917230546474
# 	지적	0.0051941643469035625
# 	선정	0.005093403160572052
# 	모니터링	0.005068580154329538
# 	사용	0.004942691419273615
# 	위반	0.004940283019095659
# 	언론	0.004863876383751631
# 	이용자	0.00473753921687603
# 	부과	0.004676820244640112
# 	현행법	0.004663033410906792
# 	매개	0.004343140404671431
# 	대중	0.004321618005633354
# 	과태료	0.004298027139157057
# 	실시간	0.00424707867205143
# 	자유	0.0042447675950825214
#
#
# Topic ID: 1
# 	정보	0.059863656759262085
# 	방송	0.04806292802095413
# 	인터넷	0.04254411533474922
# 	개인	0.03487705439329147
# 	유통	0.02403930574655533
# 	불법	0.02002403512597084
# 	사업자	0.017451658844947815
# 	규제	0.014324602670967579
# 	신문	0.013728165999054909
# 	통신	0.012834329158067703
# 	제공	0.011618741787970066
# 	신설	0.011217677965760231
# 	청소년	0.010247310623526573
# 	통신망	0.010002443566918373
# 	서비스	0.009915431030094624
# 	이용	0.007842893712222576
# 	유해	0.007595876231789589
# 	음란	0.007443949114531279
# 	조제	0.00718226982280612
# 	차단	0.007134768180549145
# 	강화	0.00660179927945137
# 	가이드라인	0.006495984736829996
# 	단체	0.006485946010798216
# 	자율	0.0064750113524496555
# 	삭제	0.006039439234882593
# 	위반	0.005837476812303066
# 	최근	0.005759947933256626
# 	모니터링	0.005718354135751724
# 	선정	0.005695262923836708
# 	다양	0.005609523039311171
# 	활동	0.005480778403580189
# 	정치	0.0054097650572657585
# 	사회	0.005366035737097263
# 	발생	0.005268157925456762
# 	보호	0.005254873540252447
# 	관리	0.005128860007971525
# 	의무	0.0051193456165492535
# 	경우	0.005108014680445194
# 	내용	0.005094258580356836
# 	콘텐츠	0.0050365072675049305
# 	지원	0.005032955668866634
# 	규정	0.005021685268729925
# 	자유	0.0049941097386181355
# 	대중	0.004922664258629084
# 	매개	0.004902560729533434
# 	시행	0.004792897496372461
# 	현행법	0.004605419933795929
# 	부과	0.004592583980411291
# 	영상	0.0045896293595433235
# 	이용자	0.0045361872762441635

# %% [markdown]
# ### 5. pyLDAvis를 통한 토픽 모델링 결과 시각화하기

# %%
# !pip install pyLDAvis

# %%
# pyLDAvis 불러오기
import pyLDAvis
import pyLDAvis.gensim

# pyLDAvis를 jupyter notebook에서 실행할 수 있게 활성화.
pyLDAvis.enable_notebook()

# pyLDAvis 실행.
data = pyLDAvis.gensim.prepare(model, corpus, dictionary)
data
# Out:
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 1      0.001969  0.0       1        1  63.192556
# 0     -0.001969  0.0       2        1  36.807444, topic_info=    Term       Freq      Total Category  logprob  loglift
# 95    불법  22.000000  22.000000  Default  30.0000  30.0000
# 176  인터넷  43.000000  43.000000  Default  29.0000  29.0000
# 137   신설  13.000000  13.000000  Default  28.0000  28.0000
# 82    방송  47.000000  47.000000  Default  27.0000  27.0000
# 4     개인  35.000000  35.000000  Default  26.0000  26.0000
# ..   ...        ...        ...      ...      ...      ...
# 223   차단   2.517013   7.084267   Topic2  -4.9981  -0.0353
# 136   신문   3.457800  12.245756   Topic2  -4.6806  -0.2651
# 205   조제   2.497953   7.095615   Topic2  -5.0057  -0.0445
# 166   음란   2.392955   7.158128   Topic2  -5.0487  -0.0962
# 113  서비스   2.596715   8.943984   Topic2  -4.9670  -0.2373
#
# [139 rows x 6 columns], token_table=      Topic      Freq   Term
# term
# 0         1  0.631514  가이드라인
# 0         2  0.315757  가이드라인
# 2         1  0.574962     강화
# 2         2  0.431221     강화
# 4         1  0.624451     개인
# ...     ...       ...    ...
# 274       2  0.417072     형성
# 277       1  0.662977     확산
# 277       2  0.662977     확산
# 279       1  0.656652     활동
# 279       2  0.492489     활동
#
# [168 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1])
